# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("microcredit.csv")
df
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 0                1      0  21408I70789   272.0   3055.050000   3065.150000
# 1                2      1  76462I70374   712.0  12122.000000  12124.750000
# 2                3      1  17943I70372   535.0   1398.000000   1398.000000
# 3                4      1  55773I70781   241.0     21.228000     21.228000
# 4                5      1  03813I82730   947.0    150.619333    150.619333
# ...            ...    ...          ...     ...           ...           ...
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111670  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228330  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0              0
# label                   0
# msisdn                  0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# ...

# %% [markdown]
# THERE IS NO NULL VALUE PRESENT IN THIS DATASET AS WE CAN SEE ABOVE

# %%
df.dtypes
# Out:
# Unnamed: 0                int64
# label                     int64
# msisdn                   object
# aon                     float64
# daily_decr30            float64
# daily_decr90            float64
# rental30                float64
# rental90                float64
# last_rech_date_ma       float64
# last_rech_date_da       float64
# last_rech_amt_ma          int64
# cnt_ma_rech30             int64
# fr_ma_rech30            float64
# sumamnt_ma_rech30       float64
# medianamnt_ma_rech30    float64
# medianmarechprebal30    float64
# cnt_ma_rech90             int64
# fr_ma_rech90              int64
# sumamnt_ma_rech90         int64
# medianamnt_ma_rech90    float64
# medianmarechprebal90    float64
# cnt_da_rech30           float64
# fr_da_rech30            float64
# cnt_da_rech90             int64
# fr_da_rech90              int64
# cnt_loans30               int64
# amnt_loans30              int64
# maxamnt_loans30         float64
# medianamnt_loans30      float64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 37 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Unnamed: 0            209593 non-null  int64
#  1   label                 209593 non-null  int64
#  2   msisdn                209593 non-null  object
#  3   aon                   209593 non-null  float64
#  4   daily_decr30          209593 non-null  float64
#  5   daily_decr90          209593 non-null  float64
#  6   rental30              209593 non-null  float64
#  7   rental90              209593 non-null  float64
#  8   last_rech_date_ma     209593 non-null  float64
#  9   last_rech_date_da     209593 non-null  float64
#  10  last_rech_amt_ma      209593 non-null  int64
#  11  cnt_ma_rech30         209593 non-null  int64
#  12  fr_ma_rech30          209593 non-null  float64
#  13  sumamnt_ma_rech30     209593 non-null  float64
# ...

# %% [markdown]
# OUR TARGET VARIABLE IS 'LABEL'=Flag indicating whether the user paid back the credit amount within 5 days of issuing the loan{1:success, 0:failure} AND COUPLE OF COLUMNS ARE NOT GOING TO AFFECT OUR TARGET VARIBALE AND THOSE COLUMNS ARE "msisdn"=mobile number of user, "pcircle"=telecom circle, "pdate"=date.
# LETS REMOVE THESE COLUMNS(DROP)

# %%
df.drop(["msisdn","pcircle","pdate","aon"],axis=1,inplace=True)

# %%
df.shape
# Out:
# (209593, 33)

# %%
sns.heatmap(df.isnull())

# %% [markdown]
# We can see in this heatmap that there is no color change which shows there is no null values present in this dataset

# %%
df.corr()
# Out:
#                       Unnamed: 0     label  daily_decr30  daily_decr90  \
# Unnamed: 0              1.000000  0.000403      0.002739      0.003077
# label                   0.000403  1.000000      0.168298      0.166150
# daily_decr30            0.002739  0.168298      1.000000      0.977704
# daily_decr90            0.003077  0.166150      0.977704      1.000000
# rental30               -0.003906  0.058085      0.442066      0.434685
# rental90               -0.003459  0.075521      0.458977      0.471730
# last_rech_date_ma      -0.001853  0.003728      0.000487      0.000908
# last_rech_date_da      -0.001133  0.001711     -0.001636     -0.001886
# last_rech_amt_ma       -0.001064  0.131804      0.275837      0.264131
# cnt_ma_rech30           0.003320  0.237331      0.451385      0.426707
# fr_ma_rech30            0.003181  0.001330     -0.000577     -0.000343
# sumamnt_ma_rech30       0.000123  0.202828      0.636536      0.603886
# ...

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(),annot=True)

# %% [markdown]
# As we can see in this heatmap the dark color boxes shows that they are negatively corelated and light color boxes are positively corelated

# %% [markdown]
# LETS DO SOME DATA VISUALISATION TECHNIQUES

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'label', 'daily_decr30', 'daily_decr90', 'rental30',
#        'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90'],
#       dtype='object')

# %%
sns.lineplot(df['daily_decr30'],df['daily_decr90'])
plt.show()

# %%
sns.lineplot(df['medianmarechprebal30'],df['label'])
plt.show()

# %%
plt.scatter(df['payback30'],df['payback90'])
plt.show()

# %%
sns.lineplot(df['maxamnt_loans30'],df['medianamnt_loans30'])
plt.show()

# %%
sns.barplot(df['cnt_loans30'],df['amnt_loans90'])
plt.show()

# %%
sns.barplot(df['medianmarechprebal30'],df['medianmarechprebal90'])
plt.show()

# %%
sns.barplot(df['cnt_ma_rech30'],df['fr_ma_rech30'])
plt.show()

# %%
df.describe()
# Out:
#           Unnamed: 0          label   daily_decr30   daily_decr90  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean   104797.000000       0.875177    5381.402289    6082.515068
# std     60504.431823       0.330519    9220.623400   10918.812767
# min         1.000000       0.000000     -93.012667     -93.012667
# 25%     52399.000000       1.000000      42.440000      42.692000
# 50%    104797.000000       1.000000    1469.175667    1500.000000
# 75%    157195.000000       1.000000    7244.000000    7802.790000
# max    209593.000000       1.000000  265926.000000  320630.000000
#
#             rental30       rental90  last_rech_date_ma  last_rech_date_da  \
# count  209593.000000  209593.000000       209593.00000      209593.000000
# mean     2692.581910    3483.406534         3755.84780        3712.202921
# std      4308.586781    5770.461279        53905.89223       53374.833430
# min    -23737.140000  -24720.580000          -29.00000         -29.000000
# ...

# %% [markdown]
# Lets check for outliers in this dataset visually by using Boxplots

# %%
plt.boxplot(df['daily_decr30'])
plt.show()

# %%
plt.boxplot(df['rental30'])
plt.show()

# %%
sns.boxplot(df['last_rech_date_ma'])
plt.show()

# %%
plt.boxplot(df['amnt_loans30'])
plt.show()

# %% [markdown]
# As we can see in these box plots that there are so many outLiers present in this dataset, let remove these outliers by using zscore

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df))
z
# Out:
# array([[1.73204254, 2.64789583, 0.25229941, ..., 0.22959366, 2.9046997 ,
#         2.39409346],
#        [1.73202602, 0.37765836, 0.73103667, ..., 0.22959366, 0.38562959,
#         0.41923266],
#        [1.73200949, 0.37765836, 0.43201111, ..., 0.22959366, 0.38562959,
#         0.41923266],
#        ...,
#        [1.73200949, 0.37765836, 0.70079045, ..., 0.22959366, 0.06820893,
#         0.04735622],
#        [1.73202602, 0.37765836, 0.77075515, ..., 0.22959366, 0.38562959,
#         0.59938541],
#        [1.73204254, 0.37765836, 0.09674426, ..., 0.22959366, 0.38562959,
#         0.41923266]])

# %%
np.where(z>5)
# Out:
# (array([    30,     53,    112, ..., 209531, 209533, 209550], dtype=int64),
#  array([ 6,  6, 19, ...,  7,  6, 28], dtype=int64))

# %%
df_1=df[(z<5).all(axis=1)]
df_1
# Out:
#         Unnamed: 0  label  daily_decr30  daily_decr90  rental30  rental90  \
# 0                1      0   3055.050000   3065.150000    220.13    260.13
# 1                2      1  12122.000000  12124.750000   3691.26   3691.26
# 2                3      1   1398.000000   1398.000000    900.13    900.13
# 3                4      1     21.228000     21.228000    159.42    159.42
# 4                5      1    150.619333    150.619333   1098.90   1098.90
# ...            ...    ...           ...           ...       ...       ...
# 209588      209589      1    151.872333    151.872333   1089.19   1089.19
# 209589      209590      1     36.936000     36.936000   1728.36   1728.36
# 209590      209591      1  11843.111670  11904.350000   5861.83   8893.20
# 209591      209592      1  12488.228330  12574.370000    411.83    984.58
# 209592      209593      1   4489.362000   4534.820000    483.92    631.20
#
#         last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# ...

# %%
df.shape
# Out:
# (209593, 33)

# %% [markdown]
# AS WE CAN SEE IN THIS DATASET THERE ARE SO MANY OUTLIERS PRESENT AND AFTER REMOVING THE OUTLIERS WE CAN CLEARLY SEE THAT THERE ARE ONLY 192398 ROWS LEFT AND AS OUTLIERS AROUND 17195 ROWS ARE DELETED

# %% [markdown]
# NOW, LETS CONSIDER OUR TARGET VARIABLE(Y) AND INDEPENDENT VARIABLE(X)

# %%
x=df_1.iloc[:,2:33]
x
# Out:
#         daily_decr30  daily_decr90  rental30  rental90  last_rech_date_ma  \
# 0        3055.050000   3065.150000    220.13    260.13                2.0
# 1       12122.000000  12124.750000   3691.26   3691.26               20.0
# 2        1398.000000   1398.000000    900.13    900.13                3.0
# 3          21.228000     21.228000    159.42    159.42               41.0
# 4         150.619333    150.619333   1098.90   1098.90                4.0
# ...              ...           ...       ...       ...                ...
# 209588    151.872333    151.872333   1089.19   1089.19                1.0
# 209589     36.936000     36.936000   1728.36   1728.36                4.0
# 209590  11843.111670  11904.350000   5861.83   8893.20                3.0
# 209591  12488.228330  12574.370000    411.83    984.58                2.0
# 209592   4489.362000   4534.820000    483.92    631.20               13.0
#
#         last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  \
# ...

# %%
y=df_1.iloc[:,1]
y
# Out:
# 0         0
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 209588    1
# 209589    1
# 209590    1
# 209591    1
# 209592    1
# Name: label, Length: 192398, dtype: int64

# %% [markdown]
# # NOW,WE HAVE TO TRAIN OUR MODEL AS PER AS OUR TARGET VARIABLE AND REQUIREMENT

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
max_acc_score=0
for r_state in range(10,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=r_state)
    logr=LogisticRegression()
    logr.fit(x_train,y_train)
    predlogr=logr.predict(x_test)
    accscore=accuracy_score(y_test,predlogr)
    if(accscore>max_acc_score):
        max_acc_score=accscore
        final_r_state=r_state
print('')
print('The Max Accuracy Score corresponds to the',final_r_state,'is',max_acc_score)
# Out:
# The Max Accuracy Score corresponds to the 66 is 0.8791580041580042

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=66)

# %%
logr.fit(x_train,y_train)
logr.score(x_train,y_train)
# Out:
# 0.8731207526085318

# %%
predlogr=logr.predict(x_test)
print('Accuracy Score',accuracy_score(y_test,predlogr))
print(confusion_matrix(y_test,predlogr))
print(classification_report(y_test,predlogr))
# Out:
# Accuracy Score 0.8791580041580042
# [[  222  4500]
#  [  150 33608]]
#               precision    recall  f1-score   support
#
#            0       0.60      0.05      0.09      4722
#            1       0.88      1.00      0.94     33758
#
#     accuracy                           0.88     38480
#    macro avg       0.74      0.52      0.51     38480
# weighted avg       0.85      0.88      0.83     38480

# %%
svm=SVC()
svm.fit(x_train,y_train)
svm.score(x_train,y_train)
predsvm=svm.predict(x_test)
print('Accuracy Score =',accuracy_score(y_test,predsvm))
print(confusion_matrix(y_test,predsvm))
print(classification_report(y_test,predsvm))
# Out:
# Accuracy Score = 0.8772869022869023
# [[    0  4722]
#  [    0 33758]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      4722
#            1       0.88      1.00      0.93     33758
#
#     accuracy                           0.88     38480
#    macro avg       0.44      0.50      0.47     38480
# weighted avg       0.77      0.88      0.82     38480

# %%
knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
knn.score(x_train,y_train)
predknn=knn.predict(x_test)
print('Accuracy-Score=',accuracy_score(y_test,predknn))
print(confusion_matrix(y_test,predknn))
print(classification_report(y_test,predknn))
# Out:
# Accuracy-Score= 0.898024948024948
# [[ 2014  2708]
#  [ 1216 32542]]
#               precision    recall  f1-score   support
#
#            0       0.62      0.43      0.51      4722
#            1       0.92      0.96      0.94     33758
#
#     accuracy                           0.90     38480
#    macro avg       0.77      0.70      0.72     38480
# weighted avg       0.89      0.90      0.89     38480

# %%
dtc=DecisionTreeClassifier()
dtc.fit(x_train,y_train)
dtc.score(x_train,y_train)
preddtc=dtc.predict(x_test)
print('Accuracy Score',accuracy_score(y_test,preddtc))
print(confusion_matrix(y_test,preddtc))
print(classification_report(y_test,preddtc))
# Out:
# Accuracy Score 0.870010395010395
# [[ 2408  2314]
#  [ 2688 31070]]
#               precision    recall  f1-score   support
#
#            0       0.47      0.51      0.49      4722
#            1       0.93      0.92      0.93     33758
#
#     accuracy                           0.87     38480
#    macro avg       0.70      0.72      0.71     38480
# weighted avg       0.87      0.87      0.87     38480

# %% [markdown]
# # ENSEMBLE TECHNIQUES

# %%
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier,GradientBoostingClassifier

# %%
rfc=RandomForestClassifier(n_estimators=200,random_state=66)
rfc.fit(x_train,y_train)
rfc.score(x_train,y_train)
predrfc=rfc.predict(x_test)
print('Accuracy Score',accuracy_score(y_test,predrfc))
print(confusion_matrix(y_test,predrfc))
print(classification_report(y_test,predrfc))
# Out:
# Accuracy Score 0.9141112266112266
# [[ 2162  2560]
#  [  745 33013]]
#               precision    recall  f1-score   support
#
#            0       0.74      0.46      0.57      4722
#            1       0.93      0.98      0.95     33758
#
#     accuracy                           0.91     38480
#    macro avg       0.84      0.72      0.76     38480
# weighted avg       0.91      0.91      0.91     38480

# %%
adc=AdaBoostClassifier(n_estimators=200,random_state=66)
adc.fit(x_train,y_train)
adc.score(x_train,y_train)
predadc=adc.predict(x_test)
print('Accuracy Score',accuracy_score(y_test,predadc))
print(confusion_matrix(y_test,predadc))
print(classification_report(y_test,predadc))
# Out:
# Accuracy Score 0.9085239085239085
# [[ 1585  3137]
#  [  383 33375]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.34      0.47      4722
#            1       0.91      0.99      0.95     33758
#
#     accuracy                           0.91     38480
#    macro avg       0.86      0.66      0.71     38480
# weighted avg       0.90      0.91      0.89     38480

# %%
gbc=GradientBoostingClassifier()
gbc.fit(x_train,y_train)
gbc.score(x_train,y_train)
predgbc=gbc.predict(x_test)
print('Accuracy Score',accuracy_score(y_test,predgbc))
print(confusion_matrix(y_test,predgbc))
print(classification_report(y_test,predgbc))
# Out:
# Accuracy Score 0.9119282744282744
# [[ 1754  2968]
#  [  421 33337]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.37      0.51      4722
#            1       0.92      0.99      0.95     33758
#
#     accuracy                           0.91     38480
#    macro avg       0.86      0.68      0.73     38480
# weighted avg       0.90      0.91      0.90     38480

# %% [markdown]
# # CROSS VALIDATION SCORE

# %%
from sklearn.model_selection import cross_val_score

# %%
logr=LogisticRegression()
logrscore=cross_val_score(logr,x,y,cv=10)
print('Scores=',logrscore)
print('Mean & STD =',logrscore.mean(),logrscore.std())
# Out:
# Scores= [0.87427235 0.87411642 0.87328482 0.87406445 0.87442827 0.8735447
#  0.8745842  0.87364865 0.87525339 0.87462966]
# Mean & STD = 0.8741826916998443 0.0005561036846097227

# %%
dtc=DecisionTreeClassifier()
dtcscore=cross_val_score(dtc,x,y,cv=10)
print('Score=',dtcscore)
print(dtcscore.mean(),dtcscore.std())
# Out:
# Score= [0.86678794 0.86247401 0.86288981 0.86595634 0.86621622 0.86268191
#  0.86928274 0.86658004 0.86667706 0.86714486]
# 0.8656690947085458 0.0021347613579535247

# %% [markdown]
# # TO SAVE THE BEST MODEL

# %%
import joblib

# %%
joblib.dump(rfc,'rfcmicrocredit.obj')
# Out:
# ['rfcmicrocredit.obj']
